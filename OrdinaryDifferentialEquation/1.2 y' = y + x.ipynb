# %%
1.2
y' = y + x

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = -20
n = 20
X, Y = np.mgrid[m:n, m:n]

# %%
dY = X+Y

# %%
plt.axes([0.025, 0.025, 1.95, 1.95])
plt.quiver(X, Y,X, dY, alpha=.9)
plt.quiver(X, Y, X, dY, edgecolor='k', facecolor='red', linewidth=.4)
plt.show()
